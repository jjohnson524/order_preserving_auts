# %%
import preserve_order

# %%
import Braid

# %%
F= Braid.FreeGroup1(8)

# %%
gens =F.gens()

# %%
gens[0]
# Out:
# x1

# %%
g=gens

# %%
g[0]
# Out:
# x1

# %%
h=F.hom([g[6],g[7],g[0],g[1],g[2],g[3],g[4],g[5]])

# %%
h(g[5])
# Out:
# x4

# %%
images = [g[0],
         g[1]**-1*g[0]*g[1]*g[0]**-1*g[1]*g[0]*g[1]**-1*g[0]**-1*g[1],
         g[0]*g[3]*g[0]**-1,
         g[0]*g[4]*g[0]**-1,
         g[0]*g[5]*g[0]**-1,
         g[1]*g[6]*g[1]**-1,
         g[1]*g[7]*g[1]**-1,
         g[2]]

# %%
images
# Out:
# [x1,
#  x2^-1*x1*x2*x1^-1*x2*x1*x2^-1*x1^-1*x2,
#  x1*x4*x1^-1,
#  x1*x5*x1^-1,
#  x1*x6*x1^-1,
#  x2*x7*x2^-1,
#  x2*x8*x2^-1,
#  x3]

# %%
h=F.hom(images)

# %%
preserve_order.preserve_order_obstruct(h,2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_10922/3847679627.py in <module>
# ----> 1 preserve_order.preserve_order_obstruct(h,2)
#
# ~/GitHub/order_preserving_auts/preserve_order.py in preserve_order_obstruct(aut, k, kact, kconj, kprod, order, track_extra_elements, add_extra_products, count, Print, tree, diagnostic)
#     494     if kprod==-1:
#     495         kprod=k
# --> 496     F = Automorphism.FreeGroup1(aut.rank)
#     497 #    if Print:
#     498 #        print('Input Braid: '+str(gens))
#
# /usr/lib/python3/dist-packages/sage/structure/element.pyx in sage.structure.element.Element.__getattr__ (build/cythonized/sage/structure/element.c:4827)()
#     492             AttributeError: 'LeftZeroSemigroup_with_category.element_class' object has no attribute 'blah_blah'
#     493         """
# --> 494         return self.getattr_from_category(name)
# ...
